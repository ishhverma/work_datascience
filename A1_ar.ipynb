# %% [markdown]
# <a href="https://colab.research.google.com/github/ishhverma/work_datascience/blob/main/A1_ar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
if __name__ == '__main__':
    print("Hello, World!")
# Out:
# Hello, World!

# %%
#!/bin/python3

import math
import os
import random
import re
import sys



if __name__ == '__main__':
    n = int(input().strip())

    if n % 2 == 1:           # odd
        print("Weird")
    else:                   # even
        if 2 <= n <= 5:
            print("Not Weird")
        elif 6 <= n <= 20:
            print("Weird")
        else:               # n > 20
            print("Not Weird")
# Out:
# 7
# Weird

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())

    print(a+b)
    print(a-b)
    print(a*b)
# Out:
# 8
# 9
# 17
# -1
# 72

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())

    print(a//b)
    print(a/b)
# Out:
# 7
# 9
# 0
# 0.7777777777777778

# %%
if __name__ == '__main__':
    n = int(input())
# Out:
# 8

# %%
def is_leap(year):
    leap = False

    # Write your logic here

    return leap

year = int(input())
print(is_leap(year))
# Out:
# 9
# False

# %%
if __name__ == '__main__':
    n = int(input())

    for i in range(1, n + 1):
        print(i, end="")
# Out:
# 9
# 123456789
