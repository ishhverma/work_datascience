# %% [markdown]
# <a href="https://colab.research.google.com/github/ishhverma/work_datascience/blob/main/Kids_With_the_Greatest_Number_of_Candies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from typing import List

class Solution:
    def kidsWithCandies(self, candies: List[int], extraCandies: int) -> List[bool]:
        max_candies = max(candies)
        return [candy + extraCandies >= max_candies for candy in candies]
